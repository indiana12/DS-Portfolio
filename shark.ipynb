# %%
import pandas as pd #pandas library

import seaborn as sns #seaborn import

import matplotlib.pyplot as plt #matplot library

shark_data = pd.read_csv(r"data/ShartankIndiaAllPitches.csv")

shark_data
# Out:
#      Episode Number  Pitch Number                Brand
# 0                 1             1  BluePine Industries  \
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               Idea
# 0                                     Frozen Momos  \
# 1    Renting e-bike for mobility in private spaces
# 2                               Detachable Sleeves
# 3                             Healthy Potato Chips
# ...

# %%
shark_data.head()
# Out:
#    Episode Number  Pitch Number                Brand
# 0               1             1  BluePine Industries  \
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             Idea
# 0                                   Frozen Momos  \
# 1  Renting e-bike for mobility in private spaces
# 2                             Detachable Sleeves
# 3                           Healthy Potato Chips
# 4                       Brain Development Course
#
#    Investment Amount (In Lakhs INR)   Debt (In lakhs INR) Equity Anupam
# 0                                 75                    0    18%      N  \
# 1                                 40                    0    50%      N
# 2                                 25                    0    30%      Y
# ...

# %%
shark_data.tail()
# Out:
#      Episode Number  Pitch Number          Brand                    Idea
# 112              34           113  Green Protein     Plant-Based Protein  \
# 113              34           114        On2Cook  Fastest Cooking Device
# 114              35           115  Jain Shikanji                Lemonade
# 115              35           116          Woloo         Washroom Finder
# 116              35           117   Elcare India    Carenting for Elders
#
#      Investment Amount (In Lakhs INR)   Debt (In lakhs INR)  Equity Anupam
# 112                                  0                    0       0      N  \
# 113                                  0                    0       0      N
# 114                                 40                    0  30.00%      Y
# 115                                  0                    0       0      N
# 116                                  0                    0       0      N
#
#     Ashneer Namita Aman Peyush Vineeta Ghazal  Season
# ...

# %%
shark_data.dtypes
# Out:
# Episode Number                        int64
# Pitch Number                          int64
# Brand                                object
# Idea                                 object
# Investment Amount (In Lakhs INR)      int64
# Debt (In lakhs INR)                   int64
# Equity                               object
# Anupam                               object
# Ashneer                              object
# Namita                               object
# Aman                                 object
# Peyush                               object
# Vineeta                              object
# Ghazal                               object
# Season                                int64
# dtype: object

# %%
Equity_per = shark_data[shark_data['Equity'] > '5']
Equity_per
# Out:
#     Episode Number  Pitch Number                Brand
# 1                1             2        Booz scooters  \
# 7                3             8            Peeschute
# 11               4            12               Bummer
# 23               8            24        Motion Breeze
# 24               9            25                Altor
# 33              12            34       Auli Lifestyle
# 39              14            40    The Renal Project
# 44              15            45              Cocofit
# 65              21            66        Sid07 Designs
# 79              25            80  Sunfox Technologies
# 81              26            82      Isak Fragrances
# 95              30            96         Kabaddi Adda
#
#                                              Idea
# 1   Renting e-bike for mobility in private spaces  \
# 7                            Disposable Urine Bag
# 11                                      Underwear
# 23                      Smart Electric Motorcycle
# ...

# %%
Investment = shark_data[shark_data['Investment Amount (In Lakhs INR) '] > 10]
Investment
# Out:
#      Episode Number  Pitch Number                           Brand
# 0                 1             1             BluePine Industries  \
# 1                 1             2                   Booz scooters
# 2                 1             3             Heart up my Sleeves
# 3                 2             4                      Tagz Foods
# 7                 3             8                       Peeschute
# 8                 3             9                            NOCD
# 9                 4            10                           Cosiq
# 11                4            12                          Bummer
# 16                6            17                    Menstrupedia
# 21                8            22                    Beyond Snack
# 22                8            23  Vivalyf Innovations- Easy Life
# 23                8            24                   Motion Breeze
# 24                9            25                           Altor
# ...

# %%
plt.scatter(shark_data.index, shark_data['Equity'])
plt.title('Shark Estate Prices')
plt.xlabel('Index Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.bar(shark_data.index, shark_data['Equity'])
plt.title('Shark Estate Prices')
plt.xlabel('Index Price')
plt.ylabel('Frequency')
plt.show()
