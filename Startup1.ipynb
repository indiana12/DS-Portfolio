# %%
import pandas as pd #importing pandas library
import seaborn as sns #importing seaborn librarys

data = pd.read_csv(r"data/startup_funding.csv") #read csv file

data #read data from file

data.head() #top five values

data.sort_values('Date dd/mm/yyyy', ascending=False)

data.groupby('City Location').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 12
#       8 data.head() #top five values
#      10 data.sort_values('Date dd/mm/yyyy', ascending=False)
# ---> 12 data.groupby('City Location').count()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:8256, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8253     raise TypeError("You have to supply one of 'by' and 'level'")
#    8254 axis = self._get_axis_number(axis)
# -> 8256 return DataFrameGroupBy(
#    8257     obj=self,
#    8258     keys=by,
#    8259     axis=axis,
#    8260     level=level,
#    8261     as_index=as_index,
#    8262     sort=sort,
#    8263     group_keys=group_keys,
#    8264     observed=observed,
#    8265     dropna=dropna,
#    8266 )
#
# ...

# %%
# Out:
# Sr No                 int64
# Date dd/mm/yyyy      object
# Startup Name         object
# Industry Vertical    object
# SubVertical          object
# City  Location       object
# Investors Name       object
# InvestmentnType      object
# Amount in USD        object
# Remarks              object
# dtype: object

# %%
# Out:
#    Sr No Date dd/mm/yyyy Startup Name Industry Vertical
# 0      1      09/01/2020       BYJU’S            E-Tech  \
# 1      2      13/01/2020       Shuttl    Transportation
#
#                  SubVertical City  Location             Investors Name
# 0                 E-learning      Bengaluru    Tiger Global Management  \
# 1  App based shuttle service        Gurgaon  Susquehanna Growth Equity
#
#         InvestmentnType Amount in USD Remarks
# 0  Private Equity Round  20,00,00,000     NaN
# 1              Series C     80,48,394     NaN

# %%
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
# Out:
#       Sr No  Date dd/mm/yyyy  Startup Name  Industry Vertical  SubVertical
# 0     False            False         False              False        False  \
# 1     False            False         False              False        False
# 2     False            False         False              False        False
# 3     False            False         False              False        False
# 4     False            False         False              False        False
# ...     ...              ...           ...                ...          ...
# 3039  False            False         False               True         True
# 3040  False            False         False               True         True
# 3041  False            False         False               True         True
# 3042  False            False         False               True         True
# 3043  False            False         False               True         True
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data['Amount in USD'] = data['Amount in USD'].str.replace(',', '').astype(float)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...
