# %%
import numpy as np #import numpy
import pandas as pd #import pandas library

import seaborn as sns #importing seaborn libraries
import matplotlib.pyplot as plt #importing matplot library

startup_data = pd.read_csv(r"data/Startups1 2.csv") #read csv
startup_data
# Out:
#      Unnamed: 0                Company       City  Starting Year
# 0             0          Urban Company    Gurgaon           2014  \
# 1             1              Classplus      Noida           2018
# 2             2                  Paytm      Noida           2010
# 3             3                   Apna     Mumbai           2019
# 4             4               Razorpay  Bengaluru           2014
# ..          ...                    ...        ...            ...
# 295         295               SafexPay      Thane           2017
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 298         298               CredFlow  New Delhi           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan  \
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# ...

# %%
startup_data.head(11) #display 11 tables
# Out:
#     Unnamed: 0        Company       City  Starting Year
# 0            0  Urban Company    Gurgaon           2014  \
# 1            1      Classplus      Noida           2018
# 2            2          Paytm      Noida           2010
# 3            3           Apna     Mumbai           2019
# 4            4       Razorpay  Bengaluru           2014
# 5            5         UpGrad     Mumbai           2015
# 6            6      Delhivery    Gurgaon           2011
# 7            7            1mg    Gurgaon           2015
# 8            8      BigBasket  Bengaluru           2011
# 9            9     GoMechanic    Gurgaon           2016
# 10          10      Unacademy  Bengaluru           2015
#
#                                              Founders
# 0   Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan  \
# 1   Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                 Akshay Khanna, Vijay Shekhar Sharma
# 3                                       Nirmit Parikh
# ...

# %%
startup_data.dtypes
# Out:
# Unnamed: 0              int64
# Company                object
# City                   object
# Starting Year           int64
# Founders               object
# Industries             object
# Description            object
# No. of Employees       object
# Funding Amount in $     int64
# Funding Round           int64
# No. of Investors        int64
# dtype: object

# %%
industry_start = startup_data[startup_data['Starting Year'] > 2019]
industry_start
# Out:
#      Unnamed: 0    Company       City  Starting Year
# 54           54    Koo App  Bengaluru           2020  \
# 76           76  Teachmint  Bengaluru           2020
# 93           93   Bimaplan  Bengaluru           2020
# 160         160     BimaPe     Mumbai           2020
# 222         222       unlu    Gurgaon           2020
# 294         294      Zolve  Bengaluru           2020
#
#                                               Founders
# 54             Aprameya Radhakrishna, Mayank Bidawatka  \
# 76   Anshuman Kumar, Divyansh Bordia, Mihir Gupta, ...
# 93                                       Not Available
# 160                                       Rahul Mathur
# 222  Akshay Pruthi, Anurag Dalia, Himanshu Periwal,...
# 294                                      Not Available
#
#                                             Industries
# 54              Apps, Internet, Social Media, Software  \
# 76                       E-Learning, EdTech, Education
# ...

# %%
city_start = startup_data[startup_data['City'] == 'Hyderabad']
city_start
# Out:
#      Unnamed: 0            Company       City  Starting Year
# 16           16        Dodla Dairy  Hyderabad           1995  \
# 29           29     Bharat Biotech  Hyderabad           1996
# 56           56  Skyroot Aerospace  Hyderabad           2018
# 223         223     KIMS Hospitals  Hyderabad           2000
# 241         241            MedPlus  Hyderabad           2006
#
#                                     Founders
# 16                            D. Sunil Reddy  \
# 29               Krishna Ella, Suchitra Ella
# 56   Naga Bharath Daka, Pawan Kumar Chandana
# 223                              Bhaskar Rao
# 241                         Madhukar Gangadi
#
#                                             Industries
# 16   Consumer Goods, Food and Beverage, Food Proces...  \
# 29                                       Biotechnology
# 56                           Aerospace, Transportation
# 223                     Health Care, Hospital, Medical
# ...

# %%
import pandas as pd

# Load data from a CSV file
startup_data = pd.read_csv(r'data/Startups1 2.csv')

# Filter by number of employees
employee_data = startup_data[startup_data['No. of Employees'] > '10']

# Display the filtered data
print(employee_data)
# Out:
#      Unnamed: 0        Company       City  Starting Year
# 0             0  Urban Company    Gurgaon           2014  \
# 1             1      Classplus      Noida           2018
# 2             2          Paytm      Noida           2010
# 3             3           Apna     Mumbai           2019
# 4             4       Razorpay  Bengaluru           2014
# ..          ...            ...        ...            ...
# 293         293          Udaan  Bengaluru           2016
# 294         294          Zolve  Bengaluru           2020
# 295         295       SafexPay      Thane           2017
# 296         296       Pariksha       Pune           2015
# 297         297          Fyllo  Bengaluru           2019
#
#                                               Founders
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan  \
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                  Akshay Khanna, Vijay Shekhar Sharma
# ...

# %%
funding_round = startup_data[startup_data['Funding Round']>2]
funding_round
# Out:
#      Unnamed: 0                Company       City  Starting Year
# 0             0          Urban Company    Gurgaon           2014  \
# 1             1              Classplus      Noida           2018
# 2             2                  Paytm      Noida           2010
# 3             3                   Apna     Mumbai           2019
# 4             4               Razorpay  Bengaluru           2014
# ..          ...                    ...        ...            ...
# 292         292               Lenskart  Faridabad           2010
# 293         293                  Udaan  Bengaluru           2016
# 296         296               Pariksha       Pune           2015
# 297         297                  Fyllo  Bengaluru           2019
# 299         299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan  \
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# ...

# %%
funding_round.head(11)
# Out:
#     Unnamed: 0        Company       City  Starting Year
# 0            0  Urban Company    Gurgaon           2014  \
# 1            1      Classplus      Noida           2018
# 2            2          Paytm      Noida           2010
# 3            3           Apna     Mumbai           2019
# 4            4       Razorpay  Bengaluru           2014
# 5            5         UpGrad     Mumbai           2015
# 6            6      Delhivery    Gurgaon           2011
# 7            7            1mg    Gurgaon           2015
# 8            8      BigBasket  Bengaluru           2011
# 9            9     GoMechanic    Gurgaon           2016
# 10          10      Unacademy  Bengaluru           2015
#
#                                              Founders
# 0   Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan  \
# 1   Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                 Akshay Khanna, Vijay Shekhar Sharma
# 3                                       Nirmit Parikh
# ...

# %%
import seaborn as sns #importing seaborn libraries
import matplotlib.pyplot as plt #importing matplot library
plt.scatter(x = 'City',y ='No. of Employees', data= startup_data, c='g', s=40)
plt.legend(['City','No. of Employees'], title='scatter_plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a histogram using seaborn
plt.figure()
sns.displot(startup_data['No. of Employees'])

# Display the plot
plt.show()

# %%
plt.figure()
sns.countplot(x = 'No. of Employees',hue='Company', data=startup_data)
plt.show()

# %%
plt.figure()
sns.lmplot(x='No. of Employees', y='Industries',  fit_reg=False, data=startup_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 plt.figure()
# ----> 2 sns.lmplot(x='No. of Employees', y='Industries',  fit_reg=False, data=startup_data)
#       3 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/regression.py:624, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     621     ax.update_datalim(xys, updatey=False)
#     622     ax.autoscale_view(scaley=False)
# --> 624 facets.map_dataframe(update_datalim, x=x, y=y)
#     626 # Draw the regression plot on each facet
# ...
